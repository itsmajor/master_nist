# %%
#!/usr/bin/env python3
# create_individual_files.py

import os
import shutil
import pandas as pd
import math
from openpyxl import Workbook
from openpyxl.styles import Font, Border, Side, Alignment
from openpyxl.utils import get_column_letter

# === Einstellungen ===
FONT = Font(name='Arial', size=8)
FONT_BOLD = Font(name='Arial', size=8, bold=True)
thin = Side(border_style='thin', color='000000')
border = Border(left=thin, right=thin, top=thin, bottom=thin)

# Hilfsfunktion: Formatiert Zahl mit sig signifikanten Ziffern, Komma als Dezimaltrennzeichen
def format_sig(x, sig=4):
    if pd.isna(x):
        return ''
    if x == 0:
        return '0'
    order = int(math.floor(math.log10(abs(x))))
    decimals = sig - 1 - order
    if decimals < 0:
        decimals = 0
    s = f"{x:.{decimals}f}"
    return s.replace('.', ',')

# Sortierreihenfolge für Modelle
MODEL_ORDER = ['Pi4b', 'Pi3b', 'PiZero2', 'PiBanana', 'PiZero', 'Pi1bPlus', 'Pi1b']

# Pfade
df_path = 'output/csv/nist_all.csv'
out_dir  = 'output/xlsx/nist_scaled'

# Output-Verzeichnis neu anlegen
if os.path.exists(out_dir):
    shutil.rmtree(out_dir)
os.makedirs(out_dir, exist_ok=True)

# CSV einlesen
raw = pd.read_csv(df_path)
raw.columns = raw.columns.str.lower()

# Pro Algorithmus verarbeiten
for algo, grp in raw.groupby('algorithmus'):
    # Picnic-Verfahren überspringen
    if algo.lower().startswith('picnic'):
        print(f"Überspringe Verfahren {algo}")
        continue
        
    safe = algo.replace('/', '_').replace(' ', '_')
    wb   = Workbook()
    ws   = wb.active
    ws.title = 'NIST All'

    # === Model-Überschrift: Merge A1:A2 und vollständiger Rahmen ===
    ws.merge_cells(start_row=1, start_column=1, end_row=2, end_column=1)
    for r in (1, 2):
        model_cell = ws.cell(row=r, column=1)
        if r == 1:
            model_cell.value = 'Model'
            model_cell.font  = FONT_BOLD
        # Alignment auch für die zweite Zelle
        model_cell.alignment = Alignment(horizontal='center', vertical='center')
        # Rahmen auf beide Zellen anwenden
        model_cell.border = border

    # Typ (kem/sig)
    typ = 'kem'
    if 'typ' in grp.columns and grp['typ'].notna().any():
        typ = str(grp['typ'].dropna().iloc[0]).lower()
    sub_map = {'Enc': 'Sign', 'Dec': 'Verify'} if typ == 'sig' else {'Enc': 'Enc', 'Dec': 'Dec'}

    # Roh-Daten
    df = pd.DataFrame({
        'model':        grp['model'],
        'keygen_time':  grp['keygen_time'],
        'enc_time':     grp['enc_time'],
        'dec_time':     grp['dec_time'],
        'keygen_heap':  grp['keygen_heap'],
        'enc_heap':     grp['enc_heap'],
        'dec_heap':     grp['dec_heap'],
        'keygen_stack': grp['keygen_stack'],
        'enc_stack':    grp['enc_stack'],
        'dec_stack':    grp['dec_stack'],
    })
    df['model'] = pd.Categorical(df['model'], categories=MODEL_ORDER, ordered=True)
    df = df.sort_values('model')

    # Dynamische Skalierung basierend auf kleinstem Wert ≥ Einheit
    # Time (µs, ms, s)
    times = df[['keygen_time','enc_time','dec_time']].values.flatten()
    nz_t = times[times > 0]
    min_t = nz_t.min() if len(nz_t) else 0
    if min_t >= 1e6:
        t_scale, t_unit = 1e6, 's'
    elif min_t >= 1e3:
        t_scale, t_unit = 1e3, 'ms'
    else:
        t_scale, t_unit = 1, 'µs'
    # Heap (B, KiB, MiB)
    heaps = df[['keygen_heap','enc_heap','dec_heap']].values.flatten()
    nz_h = heaps[heaps > 0]
    min_h = nz_h.min() if len(nz_h) else 0
    if min_h >= 2**20:
        h_scale, h_unit = 2**20, 'MiB'
    elif min_h >= 2**10:
        h_scale, h_unit = 2**10, 'KiB'
    else:
        h_scale, h_unit = 1, 'B'
    # Stack (B, KiB, MiB)
    stacks = df[['keygen_stack','enc_stack','dec_stack']].values.flatten()
    nz_s = stacks[stacks > 0]
    min_s = nz_s.min() if len(nz_s) else 0
    if min_s >= 2**20:
        s_scale, s_unit = 2**20, 'MiB'
    elif min_s >= 2**10:
        s_scale, s_unit = 2**10, 'KiB'
    else:
        s_scale, s_unit = 1, 'B'

    # Skalierung und Formatierung als Text
    if t_scale == 1:
        for col in ['keygen_time','enc_time','dec_time']:
            df[col] = df[col].apply(lambda v: '' if pd.isna(v) else str(int(v)))
    else:
        for col in ['keygen_time','enc_time','dec_time']:
            df[col] = df[col].apply(lambda v: format_sig(v/t_scale))
    for col, scale in [('keygen_heap', h_scale), ('enc_heap', h_scale), ('dec_heap', h_scale)]:
        df[col] = df[col].apply(lambda v: format_sig(v/scale))
    for col, scale in [('keygen_stack', s_scale), ('enc_stack', s_scale), ('dec_stack', s_scale)]:
        df[col] = df[col].apply(lambda v: format_sig(v/scale))

    # Header erstellen
    titles = [f'Time ({t_unit})', f'Heap ({h_unit})', f'Stack ({s_unit})']
    headers = ['Model'] + [lbl for t in titles for lbl in ['Key', sub_map['Enc'], sub_map['Dec']]]
    df.columns = headers

    # Header-Gruppen mit Rahmen
    for (title, start, end) in zip(titles, [2,5,8], [4,7,10]):
        ws.merge_cells(start_row=1, start_column=start, end_row=1, end_column=end)
        for col in range(start, end+1):
            cell = ws.cell(row=1, column=col)
            if col == start:
                cell.value     = title
                cell.font      = FONT_BOLD
                cell.alignment = Alignment(horizontal='center', vertical='center')
            cell.border    = border

    # Untertitel (Spaltenüberschriften) ab Spalte 2, Zeile 2
    for idx, hdr in enumerate(headers[1:], start=2):
        c = ws.cell(row=2, column=idx, value=hdr)
        c.font      = FONT_BOLD
        c.alignment = Alignment(horizontal='center', vertical='center')
        c.border    = border

    # Datenzeilen
    for r, row in enumerate(df.itertuples(index=False), start=3):
        for c_idx, val in enumerate(row, start=1):
            cell = ws.cell(row=r, column=c_idx, value=val)
            cell.font      = FONT
            cell.alignment = Alignment(horizontal='right', vertical='center')
            cell.border    = border

    # Spaltenbreiten anpassen
    for ci in range(1, len(headers)+1):
        letter = get_column_letter(ci)
        max_len = 0
        for rr in range(2, ws.max_row+1):
            v = ws.cell(row=rr, column=ci).value
            if v:
                max_len = max(max_len, len(str(v)))
        ws.column_dimensions[letter].width = max_len + 1

    # Zeilenhöhe
    for rr in range(1, ws.max_row+1):
        ws.row_dimensions[rr].height = 12

    wb.save(os.path.join(out_dir, f'{safe}.xlsx'))
    print(f"Einzeldatei für {algo}: {safe}.xlsx")
# Out:
# Einzeldatei für BIG_QUAKE_1: BIG_QUAKE_1.xlsx
# Einzeldatei für BIG_QUAKE_3: BIG_QUAKE_3.xlsx
# Einzeldatei für BIG_QUAKE_5: BIG_QUAKE_5.xlsx
# Einzeldatei für CRYSTALS-DILITHIUM_mode2_AES: CRYSTALS-DILITHIUM_mode2_AES.xlsx
# Einzeldatei für CRYSTALS-DILITHIUM_mode2_SHA: CRYSTALS-DILITHIUM_mode2_SHA.xlsx
# Einzeldatei für CRYSTALS-DILITHIUM_mode3_AES: CRYSTALS-DILITHIUM_mode3_AES.xlsx
# Einzeldatei für CRYSTALS-DILITHIUM_mode3_SHA: CRYSTALS-DILITHIUM_mode3_SHA.xlsx
# Einzeldatei für CRYSTALS-DILITHIUM_mode5_AES: CRYSTALS-DILITHIUM_mode5_AES.xlsx
# Einzeldatei für CRYSTALS-DILITHIUM_mode5_SHA: CRYSTALS-DILITHIUM_mode5_SHA.xlsx
# Einzeldatei für Ding_LWE: Ding_LWE.xlsx
# Einzeldatei für EMBLEM-EMBLEM: EMBLEM-EMBLEM.xlsx
# Einzeldatei für EMBLEM-R_EMBLEM: EMBLEM-R_EMBLEM.xlsx
# Einzeldatei für Falcon_1024_fpu: Falcon_1024_fpu.xlsx
# Einzeldatei für Falcon_512_fpu: Falcon_512_fpu.xlsx
# Einzeldatei für FrodoKEM-1344_AES: FrodoKEM-1344_AES.xlsx
# Einzeldatei für FrodoKEM-1344_SHAKE: FrodoKEM-1344_SHAKE.xlsx
# Einzeldatei für FrodoKEM-640_AES: FrodoKEM-640_AES.xlsx
# Einzeldatei für FrodoKEM-640_SHAKE: FrodoKEM-640_SHAKE.xlsx
# Einzeldatei für FrodoKEM-976_AES: FrodoKEM-976_AES.xlsx
# Einzeldatei für FrodoKEM-976_SHAKE: FrodoKEM-976_SHAKE.xlsx
# Einzeldatei für Gravity_SPHINCS_VERSION_S: Gravity_SPHINCS_VERSION_S.xlsx
# Einzeldatei für Gui-184: Gui-184.xlsx
# Einzeldatei für KCL-AKCN-MLWE: KCL-AKCN-MLWE.xlsx
# Einzeldatei für KCL-AKCN-MLWE-CCA: KCL-AKCN-MLWE-CCA.xlsx
# Einzeldatei für KCL-AKCN-SEC: KCL-AKCN-SEC.xlsx
# Einzeldatei für KCL-OKCN-MLWE: KCL-OKCN-MLWE.xlsx
# Einzeldatei für KCL-OKCN-SEC: KCL-OKCN-SEC.xlsx
# Einzeldatei für KINDI-256-3-4-2_encrypt: KINDI-256-3-4-2_encrypt.xlsx
# Einzeldatei für KINDI-256-3-4-2_kem: KINDI-256-3-4-2_kem.xlsx
# Einzeldatei für KINDI-256-5-2-2_encrypt: KINDI-256-5-2-2_encrypt.xlsx
# Einzeldatei für KINDI-256-5-2-2_kem: KINDI-256-5-2-2_kem.xlsx
# Einzeldatei für KINDI-512-2-2-2_encrypt: KINDI-512-2-2-2_encrypt.xlsx
# Einzeldatei für KINDI-512-2-2-2_kem: KINDI-512-2-2-2_kem.xlsx
# Einzeldatei für KINDI-512-2-4-1_encrypt: KINDI-512-2-4-1_encrypt.xlsx
# Einzeldatei für KINDI-512-2-4-1_kem: KINDI-512-2-4-1_kem.xlsx
# Einzeldatei für KINDI-512-3-2-1_encrypt: KINDI-512-3-2-1_encrypt.xlsx
# Einzeldatei für KINDI-512-3-2-1_kem: KINDI-512-3-2-1_kem.xlsx
# Einzeldatei für Lima-EncCCA_1018: Lima-EncCCA_1018.xlsx
# Einzeldatei für Lima-EncCCA_1024: Lima-EncCCA_1024.xlsx
# Einzeldatei für Lima-EncCCA_1306: Lima-EncCCA_1306.xlsx
# Einzeldatei für Lima-EncCCA_1822: Lima-EncCCA_1822.xlsx
# Einzeldatei für Lima-EncCCA_2048: Lima-EncCCA_2048.xlsx
# Einzeldatei für Lima-EncCCA_2062: Lima-EncCCA_2062.xlsx
# Einzeldatei für Lima-EncCPA_1018: Lima-EncCPA_1018.xlsx
# Einzeldatei für Lima-EncCPA_1024: Lima-EncCPA_1024.xlsx
# Einzeldatei für Lima-EncCPA_1306: Lima-EncCPA_1306.xlsx
# Einzeldatei für Lima-EncCPA_1822: Lima-EncCPA_1822.xlsx
# Einzeldatei für Lima-EncCPA_2048: Lima-EncCPA_2048.xlsx
# Einzeldatei für Lima-EncCPA_2062: Lima-EncCPA_2062.xlsx
# Einzeldatei für Lima-EncapCCA_1018: Lima-EncapCCA_1018.xlsx
# Einzeldatei für Lima-EncapCCA_1024: Lima-EncapCCA_1024.xlsx
# Einzeldatei für Lima-EncapCCA_1306: Lima-EncapCCA_1306.xlsx
# Einzeldatei für Lima-EncapCCA_1822: Lima-EncapCCA_1822.xlsx
# Einzeldatei für Lima-EncapCCA_2048: Lima-EncapCCA_2048.xlsx
# Einzeldatei für Lima-EncapCCA_2062: Lima-EncapCCA_2062.xlsx
# Einzeldatei für Lima-EncapCPA_1018: Lima-EncapCPA_1018.xlsx
# Einzeldatei für Lima-EncapCPA_1024: Lima-EncapCPA_1024.xlsx
# Einzeldatei für Lima-EncapCPA_1306: Lima-EncapCPA_1306.xlsx
# Einzeldatei für Lima-EncapCPA_1822: Lima-EncapCPA_1822.xlsx
# Einzeldatei für Lima-EncapCPA_2048: Lima-EncapCPA_2048.xlsx
# Einzeldatei für Lima-EncapCPA_2062: Lima-EncapCPA_2062.xlsx
# Einzeldatei für NTRU-Prime-ntrulpr1013: NTRU-Prime-ntrulpr1013.xlsx
# Einzeldatei für NTRU-Prime-ntrulpr1277: NTRU-Prime-ntrulpr1277.xlsx
# Einzeldatei für NTRU-Prime-ntrulpr653: NTRU-Prime-ntrulpr653.xlsx
# Einzeldatei für NTRU-Prime-ntrulpr761: NTRU-Prime-ntrulpr761.xlsx
# Einzeldatei für NTRU-Prime-ntrulpr857: NTRU-Prime-ntrulpr857.xlsx
# Einzeldatei für NTRU-Prime-ntrulpr953: NTRU-Prime-ntrulpr953.xlsx
# Einzeldatei für NTRU-Prime-sntrup1013: NTRU-Prime-sntrup1013.xlsx
# Einzeldatei für NTRU-Prime-sntrup1277: NTRU-Prime-sntrup1277.xlsx
# Einzeldatei für NTRU-Prime-sntrup653: NTRU-Prime-sntrup653.xlsx
# Einzeldatei für NTRU-Prime-sntrup761: NTRU-Prime-sntrup761.xlsx
# Einzeldatei für NTRU-Prime-sntrup857: NTRU-Prime-sntrup857.xlsx
# Einzeldatei für NTRU-Prime-sntrup953: NTRU-Prime-sntrup953.xlsx
# Einzeldatei für NTRU-Round3-ntruhps2048509: NTRU-Round3-ntruhps2048509.xlsx
# Einzeldatei für NTRU-Round3-ntruhps2048677: NTRU-Round3-ntruhps2048677.xlsx
# Einzeldatei für NTRU-Round3-ntruhps4096821: NTRU-Round3-ntruhps4096821.xlsx
# Einzeldatei für NTRU-Round3-ntruhrss701: NTRU-Round3-ntruhrss701.xlsx
# Einzeldatei für NTRUEncrypt-ntru-kem-443: NTRUEncrypt-ntru-kem-443.xlsx
# Einzeldatei für NTRUEncrypt-ntru-kem-743: NTRUEncrypt-ntru-kem-743.xlsx
# Einzeldatei für NTRU_HRSS_KEM: NTRU_HRSS_KEM.xlsx
# Einzeldatei für Odd_Manhattan_128: Odd_Manhattan_128.xlsx
# Einzeldatei für Odd_Manhattan_192: Odd_Manhattan_192.xlsx
# Einzeldatei für Odd_Manhattan_256: Odd_Manhattan_256.xlsx
# Überspringe Verfahren Picnic_3l1_OI
# Überspringe Verfahren Picnic_3l1_neon
# Überspringe Verfahren Picnic_3l3_OI
# Überspringe Verfahren Picnic_3l3_neon
# Überspringe Verfahren Picnic_3l5_OI
# Überspringe Verfahren Picnic_3l5_neon
# Überspringe Verfahren Picnic_l1fs_OI
# Überspringe Verfahren Picnic_l1fs_neon
# Überspringe Verfahren Picnic_l1full_OI
# Überspringe Verfahren Picnic_l1full_neon
# Überspringe Verfahren Picnic_l1ur_OI
# Überspringe Verfahren Picnic_l1ur_neon
# Überspringe Verfahren Picnic_l3fs_OI
# Überspringe Verfahren Picnic_l3fs_neon
# Überspringe Verfahren Picnic_l3full_OI
# Überspringe Verfahren Picnic_l3full_neon
# Überspringe Verfahren Picnic_l3ur_OI
# Überspringe Verfahren Picnic_l3ur_neon
# Überspringe Verfahren Picnic_l5fs_OI
# Überspringe Verfahren Picnic_l5fs_neon
# Überspringe Verfahren Picnic_l5full_OI
# Überspringe Verfahren Picnic_l5full_neon
# Überspringe Verfahren Picnic_l5ur_OI
# Überspringe Verfahren Picnic_l5ur_neon
# Einzeldatei für SABER: SABER.xlsx
# Einzeldatei für ThreeBears_Low_Memory_BabyBear: ThreeBears_Low_Memory_BabyBear.xlsx
# Einzeldatei für ThreeBears_Low_Memory_BabyBearEphem: ThreeBears_Low_Memory_BabyBearEphem.xlsx
# Einzeldatei für ThreeBears_Low_Memory_MamaBear: ThreeBears_Low_Memory_MamaBear.xlsx
# Einzeldatei für ThreeBears_Low_Memory_MamaBearEphem: ThreeBears_Low_Memory_MamaBearEphem.xlsx
# Einzeldatei für ThreeBears_Low_Memory_PapaBear: ThreeBears_Low_Memory_PapaBear.xlsx
# Einzeldatei für ThreeBears_Low_Memory_PapaBearEphem: ThreeBears_Low_Memory_PapaBearEphem.xlsx
# Einzeldatei für ThreeBears_OI_BabyBear: ThreeBears_OI_BabyBear.xlsx
# Einzeldatei für ThreeBears_OI_BabyBearEphem: ThreeBears_OI_BabyBearEphem.xlsx
# Einzeldatei für ThreeBears_OI_MamaBear: ThreeBears_OI_MamaBear.xlsx
# Einzeldatei für ThreeBears_OI_MamaBearEphem: ThreeBears_OI_MamaBearEphem.xlsx
# Einzeldatei für ThreeBears_OI_PapaBear: ThreeBears_OI_PapaBear.xlsx
# Einzeldatei für ThreeBears_OI_PapaBearEphem: ThreeBears_OI_PapaBearEphem.xlsx
# Einzeldatei für ThreeBears_With_Asm_BabyBear: ThreeBears_With_Asm_BabyBear.xlsx
# Einzeldatei für ThreeBears_With_Asm_BabyBearEphem: ThreeBears_With_Asm_BabyBearEphem.xlsx
# Einzeldatei für ThreeBears_With_Asm_MamaBear: ThreeBears_With_Asm_MamaBear.xlsx
# Einzeldatei für ThreeBears_With_Asm_MamaBearEphem: ThreeBears_With_Asm_MamaBearEphem.xlsx
# Einzeldatei für ThreeBears_With_Asm_PapaBear: ThreeBears_With_Asm_PapaBear.xlsx
# Einzeldatei für ThreeBears_With_Asm_PapaBearEphem: ThreeBears_With_Asm_PapaBearEphem.xlsx
# Einzeldatei für bike-1_aes: bike-1_aes.xlsx
# Einzeldatei für bike-1_sha3: bike-1_sha3.xlsx
# Einzeldatei für bike-3_aes: bike-3_aes.xlsx
# Einzeldatei für bike-3_sha3: bike-3_sha3.xlsx
# Einzeldatei für bike-5_aes: bike-5_aes.xlsx
# Einzeldatei für bike-5_sha3: bike-5_sha3.xlsx
# Einzeldatei für hqc-128: hqc-128.xlsx
# Einzeldatei für hqc-192: hqc-192.xlsx
# Einzeldatei für hqc-256: hqc-256.xlsx
# Einzeldatei für kyber1024: kyber1024.xlsx
# Einzeldatei für kyber1024-90s: kyber1024-90s.xlsx
# Einzeldatei für kyber512: kyber512.xlsx
# Einzeldatei für kyber512-90s: kyber512-90s.xlsx
# Einzeldatei für kyber768: kyber768.xlsx
# Einzeldatei für kyber768-90s: kyber768-90s.xlsx
# Einzeldatei für lotus128_encrypt: lotus128_encrypt.xlsx
# Einzeldatei für lotus128_kem: lotus128_kem.xlsx
# Einzeldatei für lotus192_encrypt: lotus192_encrypt.xlsx
# Einzeldatei für lotus192_kem: lotus192_kem.xlsx
# Einzeldatei für lotus256_encrypt: lotus256_encrypt.xlsx
# Einzeldatei für lotus256_kem: lotus256_kem.xlsx
# Einzeldatei für mceliece348864: mceliece348864.xlsx
# Einzeldatei für mceliece348864f: mceliece348864f.xlsx
# Einzeldatei für mceliece460896: mceliece460896.xlsx
# Einzeldatei für mceliece460896f: mceliece460896f.xlsx
# Einzeldatei für mceliece6688128: mceliece6688128.xlsx
# Einzeldatei für mceliece6688128f: mceliece6688128f.xlsx
# Einzeldatei für mceliece6960119: mceliece6960119.xlsx
# Einzeldatei für mceliece6960119f: mceliece6960119f.xlsx
# Einzeldatei für mceliece8192128: mceliece8192128.xlsx
# Einzeldatei für mceliece8192128f: mceliece8192128f.xlsx
# Einzeldatei für newhope1024cca: newhope1024cca.xlsx
# Einzeldatei für newhope1024cpa: newhope1024cpa.xlsx
# Einzeldatei für newhope512cca: newhope512cca.xlsx
# Einzeldatei für newhope512cpa: newhope512cpa.xlsx
# Einzeldatei für pqNTRUSign-Gaussian-1024: pqNTRUSign-Gaussian-1024.xlsx
# Einzeldatei für pqNTRUSign-Uniform-1024: pqNTRUSign-Uniform-1024.xlsx
# Einzeldatei für sphincs-haraka-128f-robust: sphincs-haraka-128f-robust.xlsx
# Einzeldatei für sphincs-haraka-128f-simple: sphincs-haraka-128f-simple.xlsx
# Einzeldatei für sphincs-haraka-128s-robust: sphincs-haraka-128s-robust.xlsx
# Einzeldatei für sphincs-haraka-128s-simple: sphincs-haraka-128s-simple.xlsx
# Einzeldatei für sphincs-haraka-192f-robust: sphincs-haraka-192f-robust.xlsx
# Einzeldatei für sphincs-haraka-192f-simple: sphincs-haraka-192f-simple.xlsx
# Einzeldatei für sphincs-haraka-192s-robust: sphincs-haraka-192s-robust.xlsx
# Einzeldatei für sphincs-haraka-192s-simple: sphincs-haraka-192s-simple.xlsx
# Einzeldatei für sphincs-haraka-256f-robust: sphincs-haraka-256f-robust.xlsx
# Einzeldatei für sphincs-haraka-256f-simple: sphincs-haraka-256f-simple.xlsx
# Einzeldatei für sphincs-haraka-256s-robust: sphincs-haraka-256s-robust.xlsx
# Einzeldatei für sphincs-haraka-256s-simple: sphincs-haraka-256s-simple.xlsx
# Einzeldatei für sphincs-sha256-128f-robust: sphincs-sha256-128f-robust.xlsx
# Einzeldatei für sphincs-sha256-128f-simple: sphincs-sha256-128f-simple.xlsx
# Einzeldatei für sphincs-sha256-128s-robust: sphincs-sha256-128s-robust.xlsx
# Einzeldatei für sphincs-sha256-128s-simple: sphincs-sha256-128s-simple.xlsx
# Einzeldatei für sphincs-sha256-192f-robust: sphincs-sha256-192f-robust.xlsx
# Einzeldatei für sphincs-sha256-192f-simple: sphincs-sha256-192f-simple.xlsx
# Einzeldatei für sphincs-sha256-192s-robust: sphincs-sha256-192s-robust.xlsx
# Einzeldatei für sphincs-sha256-192s-simple: sphincs-sha256-192s-simple.xlsx
# Einzeldatei für sphincs-sha256-256f-robust: sphincs-sha256-256f-robust.xlsx
# Einzeldatei für sphincs-sha256-256f-simple: sphincs-sha256-256f-simple.xlsx
# Einzeldatei für sphincs-sha256-256s-robust: sphincs-sha256-256s-robust.xlsx
# Einzeldatei für sphincs-sha256-256s-simple: sphincs-sha256-256s-simple.xlsx
# Einzeldatei für sphincs-shake256-128f-robust: sphincs-shake256-128f-robust.xlsx
# Einzeldatei für sphincs-shake256-128f-simple: sphincs-shake256-128f-simple.xlsx
# Einzeldatei für sphincs-shake256-128s-robust: sphincs-shake256-128s-robust.xlsx
# Einzeldatei für sphincs-shake256-128s-simple: sphincs-shake256-128s-simple.xlsx
# Einzeldatei für sphincs-shake256-192f-robust: sphincs-shake256-192f-robust.xlsx
# Einzeldatei für sphincs-shake256-192f-simple: sphincs-shake256-192f-simple.xlsx
# Einzeldatei für sphincs-shake256-192s-robust: sphincs-shake256-192s-robust.xlsx
# Einzeldatei für sphincs-shake256-192s-simple: sphincs-shake256-192s-simple.xlsx
# Einzeldatei für sphincs-shake256-256f-robust: sphincs-shake256-256f-robust.xlsx
# Einzeldatei für sphincs-shake256-256f-simple: sphincs-shake256-256f-simple.xlsx
# Einzeldatei für sphincs-shake256-256s-robust: sphincs-shake256-256s-robust.xlsx
# Einzeldatei für sphincs-shake256-256s-simple: sphincs-shake256-256s-simple.xlsx
